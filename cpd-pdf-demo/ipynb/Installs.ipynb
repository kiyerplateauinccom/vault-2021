# %%
# %load ../../load_magic/pip_install.txt

import sys

# After this has completed, run these commands in a PowerShell window:
# cd $Env:UserProfile\Documents\Repositories\space-track-scenario\ps1
# clear
# .\create_space_track_scenario_temp_environment_yml_file.ps1
command_str = f'{sys.executable} -m pip install --upgrade PyPDF2'
print(command_str)
# !{command_str}
# Out:
# C:\Users\DaveBabbitt\anaconda3\python.exe -m pip install --upgrade PyPDF2
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-py3-none-any.whl size=61085 sha256=2b820060d8f4d50e2f158928c7a95fcc8913a2d7cb7fa8053c6636e05f891d12
#   Stored in directory: c:\users\davebabbitt\appdata\local\pip\cache\wheels\b1\1a\8f\a4c34be976825a2f7948d0fa40907598d69834f8ab5889de11
# Successfully built PyPDF2
# ...

# %%
# %run ../../load_magic/dataframes
# %run ../../load_magic/soup

# %%
url = 'https://github.com/jupyter/jupyter/wiki/Jupyter-kernels'
page_soup = get_page_soup(url)
for link in page_soup.select('table')[0].select('a'):
    if link['href'].endswith('.ipynb'):
        print(link)
        !"C:\Program Files\Mozilla Firefox\firefox.exe" {link['href']}
# Out:
# <a href="https://github.com/stainlessai/micronaut-jupyter/blob/master/examples/basic-service/notebooks/use-library.ipynb">https://github.com/stainlessai/micronaut-jupyter/blob/master/examples/basic-service/notebooks/use-library.ipynb</a>
# <a href="https://mybinder.org/v2/gh/lclem/agda-kernel/master?filepath=example/LabImp.ipynb" rel="nofollow">https://mybinder.org/v2/gh/lclem/agda-kernel/master?filepath=example/LabImp.ipynb</a>
# <a href="https://nbviewer.jupyter.org/github/sourceryinstitute/jupyter-CAF-kernel/blob/master/index.ipynb" rel="nofollow">Demo</a>
# <a href="https://beta.mybinder.org/v2/gh/sourceryinstitute/jupyter-CAF-kernel/master?filepath=index.ipynb" rel="nofollow">Binder demo</a>
# <a href="https://mybinder.org/v2/gl/lfortran%2Fweb%2Flfortran-binde/master?filepath=Demo.ipynb" rel="nofollow">Binder demo</a>
# <a href="https://github.com/ansible/ansible-jupyter-kernel/blob/master/notebooks/HelloWorld.ipynb">Hello World</a>
# ...

# %%
get_page_tables(url)[0]
# Out:
# [(0, (149, 6))]
#                       Name Jupyter/IPython Version      Language(s) Version  \
# 0                   D-lang                 Jupyter                      DMD
# 1                Micronaut                     NaN  Python>=3.7.5, Groovy>3
# 2              Agda kernel                     NaN                    2.6.0
# 3    Dyalog Jupyter Kernel                     NaN             APL (Dyalog)
# 4          Coarray-Fortran             Jupyter 4.0        Fortran 2008/2015
# ..                     ...                     ...                      ...
# 144                   iTTS                     NaN        Natural languages
# 145        xeus-clickhouse                     NaN           ClickHouse SQL
# 146                IQSharp               Jupyter 4                       Q#
# 147       .Net Interactive               Jupyter 4       C#, F#, Powershell
# 148         mariadb_kernel    Jupyter Notebook/Lab                      SQL
#
# ...
